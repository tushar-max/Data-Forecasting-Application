# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("Pivot Practice.xlsx",sheet_name="Sheet5")
df.head()
# Out:
#   Country  Gender Age-Group  Year  People
# 0      C1    Male     20-40  2019       4
# 1      C1    Male     40-60  2019       6
# 2      C1    Male     60-80  2019       6
# 3      C1  Female     20-40  2019      10
# 4      C1  Female     40-60  2019       0

# %%
row = ['Country', 'Gender', 'Age-Group']
column = ['Year']
value = 'People'

# %%
pivot_table = pd.pivot_table(df, values=value, index=row, columns=column, aggfunc='sum', fill_value=0, margins=True, margins_name='Total', observed=True)
display(pivot_table)
# Out:
# Year                      2019  2020  2021  2022  2023  Total
# Country Gender Age-Group
# C1      Female 20-40        10     2     6     4    10     32
#                40-60         0     6     2     3     1     12
#                60-80         7     9     6     9     2     33
#         Male   20-40         4     5     3    10     3     25
#                40-60         6     2     8     4     5     25
#                60-80         6     6     1     5    10     28
# C2      Female 20-40         9     3     6     4     0     22
#                40-60         8     5     1     3     8     25
#                60-80         8     4     5     6     7     30
#         Male   20-40        10     0     1     9     7     27
#                40-60         8     0     5    10     0     23
#                60-80         3     1    10     1     4     19
# Total                       79    43    54    68    57    301

# %%
rdf = pd.melt(pivot_table.reset_index(),id_vars =['Country', 'Gender', 'Age-Group'],var_name = 'Year', value_name='People')
rdf
# Out:
#    Country  Gender Age-Group   Year  People
# 0       C1  Female     20-40   2019      10
# 1       C1  Female     40-60   2019       0
# 2       C1  Female     60-80   2019       7
# 3       C1    Male     20-40   2019       4
# 4       C1    Male     40-60   2019       6
# ..     ...     ...       ...    ...     ...
# 73      C2  Female     60-80  Total      30
# 74      C2    Male     20-40  Total      27
# 75      C2    Male     40-60  Total      23
# 76      C2    Male     60-80  Total      19
# 77   Total                    Total     301
#
# [78 rows x 5 columns]

# %%
np_array = pivot_table.to_numpy()

# %%
row = pivot_table.index[1]
column = pivot_table.columns[1]
print(row)
print(type(column))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\tusharawasthi\Desktop\Code\NGT-3\Untitled.ipynb Cell 7 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/tusharawasthi/Desktop/Code/NGT-3/Untitled.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> row = pivot_table.index[1]
#       <a href='vscode-notebook-cell:/c%3A/Users/tusharawasthi/Desktop/Code/NGT-3/Untitled.ipynb#W6sZmlsZQ%3D%3D?line=1'>2</a> column = pivot_table.columns[1]
#       <a href='vscode-notebook-cell:/c%3A/Users/tusharawasthi/Desktop/Code/NGT-3/Untitled.ipynb#W6sZmlsZQ%3D%3D?line=2'>3</a> print(row)
#
# NameError: name 'pivot_table' is not defined

# %%
pivot_table.rows
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13196\3955597973.py in ?()
# ----> 1 pivot_table.rows
#
# ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\generic.py in ?(self, name)
#    6200             and name not in self._accessors
#    6201             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'rows'

# %%
print(np_array)
# Out:
# [[ 10   2   6   4  10  32]
#  [  0   6   2   3   1  12]
#  [  7   9   6   9   2  33]
#  [  4   5   3  10   3  25]
#  [  6   2   8   4   5  25]
#  [  6   6   1   5  10  28]
#  [  9   3   6   4   0  22]
#  [  8   5   1   3   8  25]
#  [  8   4   5   6   7  30]
#  [ 10   0   1   9   7  27]
#  [  8   0   5  10   0  23]
#  [  3   1  10   1   4  19]
#  [ 79  43  54  68  57 301]]

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\tusharawasthi\Desktop\Code\NGT-3\Untitled.ipynb Cell 10 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/tusharawasthi/Desktop/Code/NGT-3/Untitled.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> print(np_array.index[1])
#
# AttributeError: 'numpy.ndarray' object has no attribute 'index'

# %%
pt[2019]['C1']['Female']['20-40']=20

# %%
def get_data():
    df = pd.read_excel("Pivot Practice.xlsx",sheet_name="Sheet5")
    row = ['Country', 'Gender', 'Age-Group']
    column = ['Year']
    value = 'People'
    pivot_table = pd.pivot_table(df, values=value, index=row, columns=column, aggfunc='sum', fill_value=0, margins=True, margins_name='Total', observed=True)
    # Implement logic to fetch and process data
    # Return the data in JSON format
    return pivot_table
# Out:
# Year                      2019  2020  2021  2022  2023  Total
# Country Gender Age-Group
# C1      Female 20-40        20     2     6     4    10     32
#                40-60         0     6     2     3     1     12
#                60-80         7     9     6     9     2     33
#         Male   20-40         4     5     3    10     3     25
#                40-60         6     2     8     4     5     25
#                60-80         6     6     1     5    10     28
# C2      Female 20-40         9     3     6     4     0     22
#                40-60         8     5     1     3     8     25
#                60-80         8     4     5     6     7     30
#         Male   20-40        10     0     1     9     7     27
#                40-60         8     0     5    10     0     23
#                60-80         3     1    10     1     4     19
# Total                       79    43    54    68    57    301
